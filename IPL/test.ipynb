# %%
import pickle
with open('scaler.pkl', 'rb') as f:
    loaded_scaler = pickle.load(f)

with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
import pandas as pd

# %%
df=pd.read_csv('price_crops.csv')
df.head()
# Out:
#    Unnamed: 0 Sl no. District Name          Market Name             Commodity  \
# 0         0.0      1        Mysore            K.R.Nagar  Ragi (Finger Millet)
# 1         1.0      2        Mysore            K.R.Nagar  Ragi (Finger Millet)
# 2         2.0      3        Mysore  Mysore (Bandipalya)  Ragi (Finger Millet)
# 3         3.0      4        Mysore  Mysore (Bandipalya)  Ragi (Finger Millet)
# 4         4.0      5        Mysore  Mysore (Bandipalya)  Ragi (Finger Millet)
#
#   Variety Grade  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0    Fine   FAQ                   3500.0                   3500.0
# 1    Fine   FAQ                   3800.0                   3800.0
# 2   Local   FAQ                   1900.0                   2170.0
# 3   Local   FAQ                   2001.0                   2565.0
# 4   Local   FAQ                   2039.0                   2413.0
#
#   Modal Price (Rs./Quintal)   Price Date
# 0                    3500.0  27 Oct 2023
# ...

# %%
testdata=df.drop['Unnamed: 0']
